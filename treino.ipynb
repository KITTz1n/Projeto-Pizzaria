# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
from flask import Flask, render_template, request

app = Flask(__name__)

caminho_csv1 = os.path.join(app.root_path, 'data/diametro.csv')
df = pd.read_csv(caminho_csv1)
df
# Out:
#    diametro  preco
# 0        20     40
# 1        22     45

# %%
caminho_csv2 = os.path.join(app.root_path, 'data/sabor.csv')
sabores = pd.read_csv(caminho_csv2)
for adicional in sabores['adicional']:
    print(adicional)
# Out:
# 5
# 8
# 7

# %%
df.plot(kind="line",x="diametro",y="preco");

# %%
from sklearn import linear_model

modelo = linear_model.LinearRegression()
x = df[["diametro"]]
y = df[["preco"]]

modelo.fit(x,y)
# Out:
# LinearRegression()

# %%
print(round(modelo.predict([[21]])[0][0]))
# Out:
# 52
# C:\Users\welli\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
